# %%
import os
import pandas as pd
import json

doc = pd.read_csv(os.path.join('.','test.csv'))

# %%
# with open('label.json', 'w+') as file:
#     file.write(json.dumps(list(set(doc.target))))

# %%
len(doc)
# Out:
# 1302
