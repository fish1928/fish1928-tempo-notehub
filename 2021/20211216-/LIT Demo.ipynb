# %%
from lit_nlp import notebook
from lit_nlp.api import dataset as lit_dataset
from lit_nlp.api import model as lit_model
from lit_nlp.api import types as lit_types
from lit_nlp.lib import utils

import pandas as pd

import torch
import transformers

# %%
class SR2PRDataset(lit_dataset.Dataset):
    LABELS = ["0", "1"]
    def __init__(self, split="test", max_seq_len=128):
        """Dataset constructor, loads the data into memory."""
        #raw_examples = load_tfds("imdb_reviews", split=split)
        df = pd.read_csv(f"./{split}-even.tsv", sep="\t", header=None)
        #df = df.sample(frac=1).reset_index(drop=True)
        df = df.head(50)
        texts = df[2].tolist()
        labels = df[1].tolist()
        self._examples = []  # populate this with data records
        for i in range(len(texts)):
            # format and truncate from the end to max_seq_len tokens.
            self._examples.append({
                "text": texts[i],
                "label": self.LABELS[labels[i]],
            })

    def spec(self) -> lit_types.Spec:
        """Dataset spec, which should match the model"s input_spec()."""
        return {
            "text": lit_types.TextSegment(),
            "label": lit_types.CategoryLabel(vocab=self.LABELS),
        }

# %%
datasets = {
    "SR-2-PR": SR2PRDataset()
}
# Out:
# [{'text': '[SR][MCS][Walmart] all the connectors from different datacenters are randomly going onto the deadlist, preventing all users from logging in', 'label': '1'}, {'text': '[Likely 3rd party HPE plugin][SR][CT Probate Administration] Unable to mount some of the VMFS datastore that were formatted with ATS after the host reboot', 'label': '1'}, {'text': '[SR][Marsh & McLennan Companies Inc] Need to Migrate Multi-Machines within a Deployment to a different Business Group and maintain the deployment structure', 'label': '1'}, {'text': '[18733616203][Nvidia][ESXi 6.5][vSGA]: vSGA waiver logs for P40 + R390 on ESXi 6.5', 'label': '1'}, {'text': '[DCPNc][PureStorage]Unable to validate MSCS SCSI-3 Reservations when configuring on ESXi/vCenter 6.7 with VVols', 'label': '1'}, {'text': '[18925035209][Server][VMware ESXi 6.5.0 build-7967591][CIS][UCSC-C460-M4][40540][WB: 3.5.7] Server Log Submission', 'label': '1'}, {'text': '[HP] AlterName and the standardInquiry properies of HostScsiDisk is Unset in MOB', 'label': '0'}, {'text': '[SR][University of Auckland]Data-plane impact when VM migrated from one hosts to another .', 'label': '1'}, {'text': '[SR][Honeywell] Slow Log in with writable attached', 'label': '1'}, {'text': '[SR 18746730703][Server][VMware ESXi 6.7.0 build-7535516][LVO][System x3650 M5 -[8871AC1]-][39869][WB-3.6]Server TPM Log Submission', 'label': '1'}, {'text': '[SR][19086830312][VMware Inc.][PLT] Is there support for running workflows with input field and output fields? ITSM-Plugin version 8.0', 'label': '1'}, {'text': '[18966025410][Nvidia][ESXi 6.7][vGPU]: Equivalency and Compatibility for M6 + R390 + ESXi6.7', 'label': '1'}, {'text': '[FR] Option to add service groups to firewall rules', 'label': '1'}, {'text': 'vAPI Orchestrator workflow throws HTTP ERROR 503 Service Unavailable', 'label': '1'}, {'text': '[SR][Fujitsu] Perl SDK 6.5 requires at least 6.09 version of the NET::HTTP module return the SOAP error timeout if the message lengths is a multiples of 1024', 'label': '1'}, {'text': '[API enhancement][DPM-2604][MSC][Home Depot] Custom administrator roles do not function correctly', 'label': '1'}, {'text': '[SR] Launch of published IE 11 and execute custom script brings up a blank pop-up when allowing blocked content.', 'label': '0'}, {'text': '[SR][19079401702][Vertex Inc][PLT] vRA Managed machines cannot be found within Items > Managed Machines.', 'label': '1'}, {'text': '[SR: 16300267611][VASA][VMware ESXi 5.5.0 build-1331820][IBM][IBM Storage Provider for VMware VASA][42717][WB: 3.0.0.2210122] Storage VASA Log Submission', 'label': '1'}, {'text': '[SR# 16273668610][Server][VMware ESXi 5.5.0 build-3116895][HSC][CH242 V3 DDR4][42427] [WB:3.0] Server Log Submission', 'label': '1'}, {'text': '[SR][19068120210][NTT Data Inc][PLT] Access Denied accessing vROPs Plugin via vCloud Director UI', 'label': '1'}, {'text': '[SR] [Scott Air Force Base ] Connection timeout via the WebUI (default tenant) in vRA 7.3', 'label': '1'}, {'text': '[not actionable, waiting customer][SR][19095272202][KDDI Deutschland][PLT] administrator@vsphere.local unable to change global permissions in H5 and Flex on VCSA 6.5 U2e (buttons grayed out)', 'label': '1'}, {'text': '[SR][BCS][GSS-SUSTAINING] vCenter Server 6.0 U3d vpxd windows access violation core dump when process performance statistics', 'label': '1'}, {'text': '18019256912][Nvidia][ESXi 6.7][vSGA ]: vSGA waiver logs for P4 + R400 on ESXi 6.7', 'label': '1'}, {'text': '[19061971309][NVIDIA][ESXi 6.0][vSGA][NVIDIA-VMware_ESXi_6.0_Host_Driver][367.132]: vSGA waiver logs for M60 + R367 + ESXi6.0', 'label': '1'}, {'text': '[17417360503][Intel][ESXi 6.0][NIC][i40e][2.0.6]; NIC: ESXi 6.0 i40e 2.0.6 for X710 NIC certification. Submission for driver supporting networking products based on Intel Corporation Ethernet Controller X710 for 10GbE SFP+', 'label': '1'}, {'text': '[18783969004][SRA][EMC][Dell EMC SRDF Adapter v9.0 ][45761][SRM 6.1 ]SRM Stretched logs Submission', 'label': '1'}, { ...

# %%
def _from_pretrained(cls, *args, **kw):
    """Load a transformers model in PyTorch, with fallback to TF2/Keras weights."""
    try:
        return cls.from_pretrained(*args, **kw)
    except OSError as e:
        logging.warning("Caught OSError loading model: %s", e)
        logging.warning("Re-trying to convert from TensorFlow checkpoint (from_tf=True)")
        return cls.from_pretrained(*args, from_tf=True, **kw)

class BERTClassification(lit_model.Model):
    LABELS = ["0", "1"]

    def __init__(self, model_name_or_path):
        self.tokenizer = transformers.AutoTokenizer.from_pretrained(model_name_or_path)
        model_config = transformers.AutoConfig.from_pretrained(
            model_name_or_path,
            num_labels=2,
            output_hidden_states=True,
            output_attentions=True,
        )
        # This is a just a regular PyTorch model.
        self.model = _from_pretrained(
            transformers.AutoModelForSequenceClassification,
            model_name_or_path,
            config=model_config
        )
        self.model.eval()
    
    # LIT API implementation
    def max_minibatch_size(self):
        # This tells lit_model.Model.predict() how to batch inputs to predict_minibatch().
        # Alternately, you can just override predict() and handle batching yourself.
        return 32
    
    def predict_minibatch(self, inputs):
        # Preprocess to ids and masks, and make the input batch.
        encoded_input = self.tokenizer.batch_encode_plus(
            [ex["text"] for ex in inputs],
            return_tensors="pt",
            add_special_tokens=True,
            max_length=128,
            padding="longest",
            truncation="longest_first"
        )
        

        # Check and send to cuda (GPU) if available
        #if torch.cuda.is_available():
        #    self.model.cuda()
        #    for tensor in encoded_input:
        #        encoded_input[tensor] = encoded_input[tensor].cuda()
        
        # Run a forward pass.
        with torch.no_grad():  # remove this if you need gradients.
            out: transformers.modeling_outputs.SequenceClassifierOutput = self.model(**encoded_input)
        
        # Post-process outputs.
        batched_outputs = {
            "probas": torch.nn.functional.softmax(out.logits, dim=-1),
            "input_ids": encoded_input["input_ids"],
            "ntok": torch.sum(encoded_input["attention_mask"], dim=1),
            "cls_emb": out.hidden_states[-1][:, 0],  # last layer, first token
        }
        # Return as NumPy for further processing.
        detached_outputs = {k: v.cpu().numpy() for k, v in batched_outputs.items()}
        # Unbatch outputs so we get one record per input example.
        for output in utils.unbatch_preds(detached_outputs):
            ntok = output.pop("ntok")
            output["tokens"] = self.tokenizer.convert_ids_to_tokens(output.pop("input_ids")[1:ntok - 1])
            yield output
            
    def input_spec(self) -> lit_types.Spec:
        return {
            "text": lit_types.TextSegment(),
            "label": lit_types.CategoryLabel(vocab=self.LABELS, required=False)
        }

    def output_spec(self) -> lit_types.Spec:
        return {
            "tokens": lit_types.Tokens(),
            "probas": lit_types.MulticlassPreds(parent="label", vocab=self.LABELS),
            "cls_emb": lit_types.Embeddings()
        }

# %%
models = {"SR-2-PR": BERTClassification(".")}
# Out:
# INFO:absl:Received 50 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:51:35] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['RegressionScore']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:51:35] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=RegressionScore HTTP/1.1" 200 200
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['Scalar']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:51:35] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=Scalar HTTP/1.1" 200 200
# 127.0.0.1 - - [18/May/2021 08:51:35] "GET /static/potato.svg HTTP/1.1" 200 3717

# %%
widget = notebook.LitWidget(models, datasets, height=1024)
# Out:
# INFO:absl:
#  (    (
#  )\ ) )\ )  *   )
# (()/((()/(` )  /(
#  /(_))/(_))( )(_))
# (_)) (_)) (_(_())
# | |  |_ _||_   _|
# | |__ | |   | |
# |____|___|  |_|
#
#
# INFO:absl:Starting LIT server...
# INFO:absl:CachingModelWrapper 'SR-2-PR': no cache path specified, not loading.

# %%
# Render the widget
widget.render()
# Out:
#     <style>div.output_scroll { height: 1034px; }</style>
#     <iframe id='lit-frame-9d7345ef9d6f543d' width='100%' height='1024' frameborder='0'>
#     </iframe>
#     <script>
#       (function() {
#         const frame = document.getElementById("lit-frame-9d7345ef9d6f543d");
#         const url = new URL("/", window.location);
#         const port = 16629;
#         if (port) {
#           url.port = port;
#         }
#         frame.src = url;
#       })();
#     </script>
# 127.0.0.1 - - [18/May/2021 08:56:10] "GET / HTTP/1.1" 200 1408
# 127.0.0.1 - - [18/May/2021 08:56:10] "GET /main.js HTTP/1.1" 200 1661454
# 127.0.0.1 - - [18/May/2021 08:56:10] "POST /get_info? HTTP/1.1" 200 8539
# 127.0.0.1 - - [18/May/2021 08:56:10] "GET /static/favicon.png HTTP/1.1" 200 13257
# INFO:absl:0 of 0 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:56:52] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:56:52] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:56:52] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Found text fields for LIME attribution: ['text']
# INFO:absl:Explaining: [SR][BCS][DHL] vRA 6.2.5 -> Reconfigure VM fails with "A reconfigure operation for this machine is already in progress"
# WARNING:absl:CachingModelWrapper.predict() bypasses the cache - if this is not intended, use predict_with_metadata() instead to access cache via example IDs.
# 127.0.0.1 - - [18/May/2021 08:57:13] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=LIME HTTP/1.1" 200 667
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:57:21] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:57:55] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 195
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:57:55] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:57:55] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:57:55] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Found text fields for LIME attribution: ['text']
# INFO:absl:Explaining: [SR][MCS][Walmart] all the connectors from different datacenters are randomly going onto the deadlist, preventing all users from logging in
# WARNING:absl:CachingModelWrapper.predict() bypasses the cache - if this is not intended, use predict_with_metadata() instead to access cache via example IDs.
# 127.0.0.1 - - [18/May/2021 08:58:11] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=LIME HTTP/1.1" 200 701
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:58:11] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 195
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:58:11] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:12] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['RegressionScore']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=RegressionScore HTTP/1.1" 200 200
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['Scalar']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=Scalar HTTP/1.1" 200 200
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 195
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 196
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:19] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 195
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 196
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Projection request: instance key: frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})
# INFO:absl:CachingModelWrapper 'frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})': misses (dataset=): []
# INFO:absl:CachingModelWrapper 'frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=umap HTTP/1.1" 200 3379
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['RegressionScore']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=RegressionScore HTTP/1.1" 200 200
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['Scalar']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=Scalar HTTP/1.1" 200 200
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 08:59:27] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 54
# INFO:absl:1 of 1 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 1 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Found text fields for LIME attribution: ['text']
# INFO:absl:Explaining: [SR][MCS][Walmart] all the connectors from different datacenters are randomly going onto the deadlist, preventing all users from logging in
# WARNING:absl:CachingModelWrapper.predict() bypasses the cache - if this is not intended, use predict_with_metadata() instead to access cache via example IDs.
# 127.0.0.1 - - [18/May/2021 08:59:49] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=LIME HTTP/1.1" 200 694
# 127.0.0.1 - - [18/May/2021 09:46:29] "GET / HTTP/1.1" 200 1408
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_info? HTTP/1.1" 200 8539
# INFO:absl:0 of 0 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_dataset?dataset_name=SR-2-PR HTTP/1.1" 200 10095
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Projection request: instance key: frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})
# INFO:absl:CachingModelWrapper 'frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})': misses (dataset=): []
# INFO:absl:CachingModelWrapper 'frozenset({('model_name', 'SR-2-PR'), ('field_name', 'cls_emb'), ('proj_kw', frozenset({('n_components', 3)})), ('dataset_name', 'SR-2-PR')})': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=umap HTTP/1.1" 200 3379
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_interpretations?model=SR-2-PR&dataset_name=SR-2-PR&interpreter=metrics HTTP/1.1" 200 196
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['MulticlassPreds']
# INFO:absl:Will return keys: {'probas'}
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=MulticlassPreds HTTP/1.1" 200 2714
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['RegressionScore']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=RegressionScore HTTP/1.1" 200 200
# INFO:absl:50 of 50 inputs sent as IDs; reconstituting from dataset 'SR-2-PR'
# INFO:absl:CachingModelWrapper 'SR-2-PR': misses (dataset=SR-2-PR): []
# INFO:absl:CachingModelWrapper 'SR-2-PR': 0 misses out of 50 inputs
# INFO:absl:Prepared 0 inputs for model
# INFO:absl:Received 0 predictions from model
# INFO:absl:Requested types: ['Scalar']
# INFO:absl:Will return keys: set()
# 127.0.0.1 - - [18/May/2021 09:46:30] "POST /get_preds?model=SR-2-PR&dataset_name=SR-2-PR&requested_types=Scalar HTTP/1.1" 200 200
