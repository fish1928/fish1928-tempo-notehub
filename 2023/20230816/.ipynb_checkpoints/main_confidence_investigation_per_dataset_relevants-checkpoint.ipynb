# %%
import json
import os
import sys
from datetime import datetime
import pandas as pd
import torch
from torch import BoolTensor
from transformers import DistilBertTokenizerFast, DistilBertForSequenceClassification, EarlyStoppingCallback
from transformers import Trainer, TrainingArguments
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

MODEL_NAME = 'distilbert-base-uncased'
MAX_LENGTH = 512

DIR_OUTPUT = 'results'
DEVICE_DEFAULT = 'cuda'


def get_ts():
    return datetime.utcnow().replace(microsecond=0).isoformat()
# end


class SimpleDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
        item["labels"] = torch.tensor([self.labels[idx]])
        return item

    def __len__(self):
        return len(self.labels)
    # end
# end

def read_passages(path_data, path_label, test_size=0):
    df = pd.read_csv(path_data)

    documents_1 = df['processed'].to_list()
    documents_2 = df['targetnew'].to_list()                                  
    
    documents_2 = [f'is {document_2} problem' for document_2 in documents_2]
                                      
    labels_str = df['label'].to_list()

    samples = [(d_1, d_2) for d_1, d_2 in zip(documents_1, documents_2)]

    with open(path_label, 'r') as file:
        labels_list = sorted(json.load(file))
    # end

    labels_all = {l: idx for idx, l in enumerate(labels_list)}

    labels = [labels_all[label_str] for label_str in labels_str]

    if test_size > 0:
        return train_test_split(samples, labels, test_size=test_size, stratify=labels, random_state=234), labels_list
    else:
        return (samples, samples, labels, labels), labels_list
    # end
# end


def compute_metrics(pred):
    labels = pred.label_ids.reshape(-1)
    preds = pred.predictions.argmax(-1).reshape(-1)

    accuracy = accuracy_score(y_true=labels, y_pred=preds)
    precision = precision_score(y_true=labels, y_pred=preds, zero_division=1, average='macro')
    recall = recall_score(y_true=labels, y_pred=preds, zero_division=1, average='macro')
    f1 = f1_score(y_true=labels, y_pred=preds, zero_division=1, average='macro')

    return {"accuracy": accuracy, "precision": precision, "recall": recall, "f1": f1}
# end

def predict_plus(input_tokenized, model):

    out = model(**input_tokenized.to(DEVICE_DEFAULT), output_attentions=True)
    logits = out.logits.cpu()
    return logits
# end

def main_train_and_evaluate(name_train, path_train, path_label, path_test, path_output):
    print('[{}] start main_train_and_evaluate with {} {}'.format(get_ts(), path_train, path_test))

    model_name = MODEL_NAME
    max_length = MAX_LENGTH
    output_dir = DIR_OUTPUT

    (train_samples, valid_samples, train_labels, valid_labels), target_names = read_passages(path_train, path_label, 0.1)
    
    # # TODO: DEBUG
    # train_samples = train_samples[:500]
    # train_labels = train_labels[:500]
    # valid_samples = valid_samples[:100]
    # valid_labels = valid_labels[:100]
    # ###

    tokenizer = DistilBertTokenizerFast.from_pretrained(model_name, do_lower_case=True)
                                      
    train_encodings = tokenizer.batch_encode_plus(train_samples, truncation=True, padding=True, max_length=max_length,
                                                  return_tensors='pt')
                                      
    valid_encodings = tokenizer.batch_encode_plus(valid_samples, truncation=True, padding=True, max_length=max_length,
                                                  return_tensors='pt')

    train_dataset = SimpleDataset(train_encodings, train_labels)
    valid_dataset = SimpleDataset(valid_encodings, valid_labels)

    model = DistilBertForSequenceClassification.from_pretrained(model_name, num_labels=len(target_names))

    training_args = TrainingArguments(
        output_dir=output_dir,  # output directory
        num_train_epochs=8,  # total number of training epochs
        per_device_train_batch_size=8,  # batch size per device during training
        per_device_eval_batch_size=8,  # batch size for evaluation
        warmup_steps=0,  # number of warmup steps for learning rate scheduler
        weight_decay=0.01,  # strength of weight decay
        logging_dir='./logs',  # directory for storing logs
        load_best_model_at_end=True,
        # load the best model when finished training (default metric is loss)    # but you can specify `metric_for_best_model` argument to change to accuracy or other metric
        logging_steps=1,  # log & save weights each logging_steps
        evaluation_strategy="epoch",  # evaluate each `logging_steps`
        learning_rate=2e-5,
        save_strategy='epoch',
        save_total_limit=5,
        metric_for_best_model='f1'
    )

    trainer = Trainer(
        model=model,  # the instantiated Transformers model to be trained
        args=training_args,  # training arguments, defined above
        train_dataset=train_dataset,  # training dataset
        eval_dataset=valid_dataset,  # evaluation dataset
        compute_metrics=compute_metrics,  # the callback that computes metrics of interest
        callbacks=[EarlyStoppingCallback(early_stopping_patience=3)]
    )

    # trainer = Trainer(
    #     model=model,  # the instantiated Transformers model to be trained
    #     args=training_args,  # training arguments, defined above
    #     train_dataset=train_dataset,  # training dataset
    #     eval_dataset=valid_dataset,  # evaluation dataset
    #     compute_metrics=compute_metrics
    # )

    print('[{}] start training...'.format(get_ts()))
    trainer.train()

    info_state_model = trainer.evaluate()
    print('[{}] finish training.'.format(get_ts()))

    ################## start to do eval ##################

    (samples_test, _, indexs_label_test, _), target_names = read_passages(path_test, path_label, 0)
    labels_test = [target_names[index_label_test] for index_label_test in indexs_label_test]

    list_conf_output = []
    list_label_output = []
    list_answer_output = []

    for sample_test, label_origin in zip(samples_test, labels_test):
        input_tokenized = tokenizer.encode_plus(sample_test, padding=True, truncation=True, max_length=max_length,
                                                return_tensors='pt')
        with torch.no_grad():
            # out = model(**input_tokenized, output_hidden_states=True, output_attentions=True)
            logits_this = predict_plus(input_tokenized, model)
        # end

        probas_evaluate = torch.nn.functional.softmax(logits_this, dim=-1)
        answer_evaluate = int(probas_evaluate.argmax())
        label_evaluate = target_names[answer_evaluate]

        list_conf_output.append(probas_evaluate.numpy().tolist()[0][answer_evaluate])
        list_label_output.append(label_evaluate)
        list_answer_output.append(label_origin)
    # end

    print('[{}] finish testing.'.format(get_ts()))

    pairs_label_conf = [[a, b, c] for a, b, c in zip(list_label_output, list_conf_output, list_answer_output)]

    filename_output = f'output-{name_train}.json'
    path_file_output = os.path.join(path_output, filename_output)

    with open(path_file_output, 'w+') as file:
        file.write(json.dumps(pairs_label_conf))
    # end

    print('[{}] main_train_and_evaluate finished.'.format(get_ts()))
    
    return model
# end

# %%
path_folder_train = 'data_model_relevants'
path_label = 'labels.json'
path_output = 'output_noseed_anchor'

os.makedirs(path_output, exist_ok=True)

import numpy as np
import random
import torch

seed_val = 234
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

import os
import subprocess

filenames = sorted([filename for filename in os.listdir(path_folder_train) if filename[0] != '.' and 'train' in filename])
model_last = None

for _filename in filenames:
    filename_base = _filename.split('_')[0]
    
    filename_test = f'{filename_base}_test.csv'
    filename_train = _filename
    
    
    path_train = os.path.join(path_folder_train, filename_train)
    path_test = os.path.join(path_folder_train, filename_test)
    
    model_last = main_train_and_evaluate(filename_base, path_train, path_label, path_test, path_output)

    subprocess.run("rm -rf results", shell=True)
    # subprocess.run("rm -rf mlruns", shell=True)
# end
# Out:
# [2023-08-30T08:58:52] start main_train_and_evaluate with data_model_relevants/202206171000_train_0.35_15.csv data_model_relevants/202206171000_test.csv
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ***** Running training *****
#   Num examples = 35154
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 35160
# [2023-08-30T08:59:07] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='35160' max='35160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [35160/35160 1:41:12, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000700</td>
#       <td>0.065627</td>
#       <td>0.985151</td>
#       <td>0.985397</td>
#       <td>0.985151</td>
#       <td>0.985149</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000200</td>
#       <td>0.015510</td>
#       <td>0.996928</td>
#       <td>0.996930</td>
#       <td>0.996928</td>
#       <td>0.996928</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.013409</td>
#       <td>0.997440</td>
#       <td>0.997440</td>
#       <td>0.997440</td>
#       <td>0.997440</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000300</td>
#       <td>0.022975</td>
#       <td>0.996928</td>
#       <td>0.996947</td>
#       <td>0.996928</td>
#       <td>0.996928</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.010037</td>
#       <td>0.998720</td>
#       <td>0.998723</td>
#       <td>0.998720</td>
#       <td>0.998720</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.015388</td>
#       <td>0.997952</td>
#       <td>0.997960</td>
#       <td>0.997952</td>
#       <td>0.997952</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.009748</td>
#       <td>0.998720</td>
#       <td>0.998721</td>
#       <td>0.998720</td>
#       <td>0.998720</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.010133</td>
#       <td>0.998720</td>
#       <td>0.998723</td>
#       <td>0.998720</td>
#       <td>0.998720</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-4395
# Configuration saved in results/checkpoint-4395/config.json
# Model weights saved in results/checkpoint-4395/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-8790
# Configuration saved in results/checkpoint-8790/config.json
# Model weights saved in results/checkpoint-8790/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-13185
# Configuration saved in results/checkpoint-13185/config.json
# Model weights saved in results/checkpoint-13185/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-17580
# Configuration saved in results/checkpoint-17580/config.json
# Model weights saved in results/checkpoint-17580/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-21975
# Configuration saved in results/checkpoint-21975/config.json
# Model weights saved in results/checkpoint-21975/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-26370
# Configuration saved in results/checkpoint-26370/config.json
# Model weights saved in results/checkpoint-26370/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-4395] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-30765
# Configuration saved in results/checkpoint-30765/config.json
# Model weights saved in results/checkpoint-30765/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-8790] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-35160
# Configuration saved in results/checkpoint-35160/config.json
# Model weights saved in results/checkpoint-35160/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-13185] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/checkpoint-30765 (score: 0.9987199173196366).
# ***** Running Evaluation *****
#   Num examples = 3906
#   Batch size = 8
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='489' max='489' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [489/489 00:21]
#     </div>
# [2023-08-30T10:40:44] finish training.
# [2023-08-30T10:40:49] finish testing.
# [2023-08-30T10:40:49] main_train_and_evaluate finished.
# [2023-08-30T10:40:52] start main_train_and_evaluate with data_model_relevants/202207021500_train_0.35_15.csv data_model_relevants/202207021500_test.csv
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /home/jovyan/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /home/jovyan/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/jovyan/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at /home/jovyan/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 38556
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 38560
# [2023-08-30T10:41:03] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='38560' max='38560' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [38560/38560 1:50:37, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.001400</td>
#       <td>0.079722</td>
#       <td>0.981326</td>
#       <td>0.981333</td>
#       <td>0.981326</td>
#       <td>0.981326</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000300</td>
#       <td>0.063774</td>
#       <td>0.988796</td>
#       <td>0.988823</td>
#       <td>0.988796</td>
#       <td>0.988795</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.032414</td>
#       <td>0.994631</td>
#       <td>0.994632</td>
#       <td>0.994631</td>
#       <td>0.994631</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.037199</td>
#       <td>0.994865</td>
#       <td>0.994872</td>
#       <td>0.994865</td>
#       <td>0.994865</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.043727</td>
#       <td>0.993697</td>
#       <td>0.993703</td>
#       <td>0.993697</td>
#       <td>0.993697</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.027021</td>
#       <td>0.996965</td>
#       <td>0.996979</td>
#       <td>0.996965</td>
#       <td>0.996965</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.035422</td>
#       <td>0.996732</td>
#       <td>0.996743</td>
#       <td>0.996732</td>
#       <td>0.996732</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.030583</td>
#       <td>0.996499</td>
#       <td>0.996507</td>
#       <td>0.996499</td>
#       <td>0.996499</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-4820
# Configuration saved in results/checkpoint-4820/config.json
# Model weights saved in results/checkpoint-4820/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-9640
# Configuration saved in results/checkpoint-9640/config.json
# Model weights saved in results/checkpoint-9640/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-14460
# Configuration saved in results/checkpoint-14460/config.json
# Model weights saved in results/checkpoint-14460/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-19280
# Configuration saved in results/checkpoint-19280/config.json
# Model weights saved in results/checkpoint-19280/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-24100
# Configuration saved in results/checkpoint-24100/config.json
# Model weights saved in results/checkpoint-24100/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-28920
# Configuration saved in results/checkpoint-28920/config.json
# Model weights saved in results/checkpoint-28920/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-4820] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-33740
# Configuration saved in results/checkpoint-33740/config.json
# Model weights saved in results/checkpoint-33740/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-9640] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-38560
# Configuration saved in results/checkpoint-38560/config.json
# Model weights saved in results/checkpoint-38560/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-14460] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/checkpoint-28920 (score: 0.9969654328407493).
# ***** Running Evaluation *****
#   Num examples = 4284
#   Batch size = 8
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='536' max='536' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [536/536 00:23]
#     </div>
# [2023-08-30T12:32:07] finish training.
# [2023-08-30T12:32:08] finish testing.
# [2023-08-30T12:32:08] main_train_and_evaluate finished.
# [2023-08-30T12:32:11] start main_train_and_evaluate with data_model_relevants/202207041600_train_0.35_15.csv data_model_relevants/202207041600_test.csv
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /home/jovyan/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /home/jovyan/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/jovyan/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at /home/jovyan/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 39123
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 39128
# [2023-08-30T12:32:23] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='39128' max='39128' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [39128/39128 1:50:49, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000200</td>
#       <td>0.077371</td>
#       <td>0.983437</td>
#       <td>0.983505</td>
#       <td>0.983438</td>
#       <td>0.983436</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000400</td>
#       <td>0.052792</td>
#       <td>0.991028</td>
#       <td>0.991031</td>
#       <td>0.991029</td>
#       <td>0.991028</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000700</td>
#       <td>0.022013</td>
#       <td>0.995859</td>
#       <td>0.995861</td>
#       <td>0.995859</td>
#       <td>0.995859</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.015423</td>
#       <td>0.997239</td>
#       <td>0.997241</td>
#       <td>0.997240</td>
#       <td>0.997239</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.012727</td>
#       <td>0.998160</td>
#       <td>0.998160</td>
#       <td>0.998160</td>
#       <td>0.998160</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.016903</td>
#       <td>0.997470</td>
#       <td>0.997470</td>
#       <td>0.997469</td>
#       <td>0.997470</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.013716</td>
#       <td>0.998390</td>
#       <td>0.998390</td>
#       <td>0.998390</td>
#       <td>0.998390</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.010564</td>
#       <td>0.998850</td>
#       <td>0.998850</td>
#       <td>0.998850</td>
#       <td>0.998850</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-4891
# Configuration saved in results/checkpoint-4891/config.json
# Model weights saved in results/checkpoint-4891/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-9782
# Configuration saved in results/checkpoint-9782/config.json
# Model weights saved in results/checkpoint-9782/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-14673
# Configuration saved in results/checkpoint-14673/config.json
# Model weights saved in results/checkpoint-14673/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-19564
# Configuration saved in results/checkpoint-19564/config.json
# Model weights saved in results/checkpoint-19564/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-24455
# Configuration saved in results/checkpoint-24455/config.json
# Model weights saved in results/checkpoint-24455/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-29346
# Configuration saved in results/checkpoint-29346/config.json
# Model weights saved in results/checkpoint-29346/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-4891] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-34237
# Configuration saved in results/checkpoint-34237/config.json
# Model weights saved in results/checkpoint-34237/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-9782] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-39128
# Configuration saved in results/checkpoint-39128/config.json
# Model weights saved in results/checkpoint-39128/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-14673] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/checkpoint-39128 (score: 0.9988497814584771).
# ***** Running Evaluation *****
#   Num examples = 4347
#   Batch size = 8
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='544' max='544' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [544/544 00:24]
#     </div>
# [2023-08-30T14:23:38] finish training.
# [2023-08-30T14:23:40] finish testing.
# [2023-08-30T14:23:40] main_train_and_evaluate finished.
# [2023-08-30T14:23:43] start main_train_and_evaluate with data_model_relevants/202207151000_train_0.35_15.csv data_model_relevants/202207151000_test.csv
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /home/jovyan/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /home/jovyan/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/jovyan/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at /home/jovyan/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 40068
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 40072
# [2023-08-30T14:23:54] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='40072' max='40072' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [40072/40072 1:54:30, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000900</td>
#       <td>0.069047</td>
#       <td>0.984726</td>
#       <td>0.984728</td>
#       <td>0.984726</td>
#       <td>0.984726</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.030238</td>
#       <td>0.993711</td>
#       <td>0.993717</td>
#       <td>0.993711</td>
#       <td>0.993711</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.019313</td>
#       <td>0.995508</td>
#       <td>0.995514</td>
#       <td>0.995508</td>
#       <td>0.995508</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.002800</td>
#       <td>0.024552</td>
#       <td>0.996181</td>
#       <td>0.996204</td>
#       <td>0.996181</td>
#       <td>0.996181</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.012915</td>
#       <td>0.997978</td>
#       <td>0.997979</td>
#       <td>0.997978</td>
#       <td>0.997978</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.019441</td>
#       <td>0.997529</td>
#       <td>0.997532</td>
#       <td>0.997529</td>
#       <td>0.997529</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.017558</td>
#       <td>0.997529</td>
#       <td>0.997537</td>
#       <td>0.997529</td>
#       <td>0.997529</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.019128</td>
#       <td>0.997754</td>
#       <td>0.997760</td>
#       <td>0.997754</td>
#       <td>0.997754</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-5009
# Configuration saved in results/checkpoint-5009/config.json
# Model weights saved in results/checkpoint-5009/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-10018
# Configuration saved in results/checkpoint-10018/config.json
# Model weights saved in results/checkpoint-10018/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-15027
# Configuration saved in results/checkpoint-15027/config.json
# Model weights saved in results/checkpoint-15027/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-20036
# Configuration saved in results/checkpoint-20036/config.json
# Model weights saved in results/checkpoint-20036/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-25045
# Configuration saved in results/checkpoint-25045/config.json
# Model weights saved in results/checkpoint-25045/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-30054
# Configuration saved in results/checkpoint-30054/config.json
# Model weights saved in results/checkpoint-30054/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-5009] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-35063
# Configuration saved in results/checkpoint-35063/config.json
# Model weights saved in results/checkpoint-35063/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-10018] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-40072
# Configuration saved in results/checkpoint-40072/config.json
# Model weights saved in results/checkpoint-40072/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-15027] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/checkpoint-25045 (score: 0.9979784365556874).
# ***** Running Evaluation *****
#   Num examples = 4452
#   Batch size = 8
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='557' max='557' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [557/557 00:24]
#     </div>
# [2023-08-30T16:18:51] finish training.
# [2023-08-30T16:18:53] finish testing.
# [2023-08-30T16:18:53] main_train_and_evaluate finished.
# [2023-08-30T16:18:56] start main_train_and_evaluate with data_model_relevants/202207221500_train_0.35_15.csv data_model_relevants/202207221500_test.csv
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /home/jovyan/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /home/jovyan/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/jovyan/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
# ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 52920
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 52920
# [2023-08-31T01:30:04] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='52920' max='52920' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [52920/52920 2:30:48, Epoch 8/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000400</td>
#       <td>0.041377</td>
#       <td>0.990136</td>
#       <td>0.990246</td>
#       <td>0.990136</td>
#       <td>0.990136</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.028957</td>
#       <td>0.993367</td>
#       <td>0.993398</td>
#       <td>0.993367</td>
#       <td>0.993367</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000100</td>
#       <td>0.042904</td>
#       <td>0.994048</td>
#       <td>0.994048</td>
#       <td>0.994048</td>
#       <td>0.994048</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000000</td>
#       <td>0.028866</td>
#       <td>0.996259</td>
#       <td>0.996259</td>
#       <td>0.996259</td>
#       <td>0.996259</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000000</td>
#       <td>0.031680</td>
#       <td>0.996088</td>
#       <td>0.996089</td>
#       <td>0.996088</td>
#       <td>0.996088</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000000</td>
#       <td>0.017736</td>
#       <td>0.998129</td>
#       <td>0.998131</td>
#       <td>0.998129</td>
#       <td>0.998129</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000000</td>
#       <td>0.028500</td>
#       <td>0.997619</td>
#       <td>0.997625</td>
#       <td>0.997619</td>
#       <td>0.997619</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000000</td>
#       <td>0.027623</td>
#       <td>0.997959</td>
#       <td>0.997963</td>
#       <td>0.997959</td>
#       <td>0.997959</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-6615
# Configuration saved in results/checkpoint-6615/config.json
# Model weights saved in results/checkpoint-6615/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-13230
# Configuration saved in results/checkpoint-13230/config.json
# Model weights saved in results/checkpoint-13230/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-19845
# Configuration saved in results/checkpoint-19845/config.json
# Model weights saved in results/checkpoint-19845/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-26460
# Configuration saved in results/checkpoint-26460/config.json
# Model weights saved in results/checkpoint-26460/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-33075
# Configuration saved in results/checkpoint-33075/config.json
# Model weights saved in results/checkpoint-33075/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-39690
# Configuration saved in results/checkpoint-39690/config.json
# Model weights saved in results/checkpoint-39690/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-6615] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-46305
# Configuration saved in results/checkpoint-46305/config.json
# Model weights saved in results/checkpoint-46305/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-13230] due to args.save_total_limit
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-52920
# Configuration saved in results/checkpoint-52920/config.json
# Model weights saved in results/checkpoint-52920/pytorch_model.bin
# Deleting older checkpoint [results/checkpoint-19845] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from results/checkpoint-39690 (score: 0.9981292503479817).
# ***** Running Evaluation *****
#   Num examples = 5880
#   Batch size = 8
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='735' max='735' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [735/735 00:32]
#     </div>
# [2023-08-31T04:01:27] finish training.
# [2023-08-31T04:01:28] finish testing.
# [2023-08-31T04:01:28] main_train_and_evaluate finished.
# [2023-08-31T04:01:31] start main_train_and_evaluate with data_model_relevants/202208240500_train_0.35_15.csv data_model_relevants/202208240500_test.csv
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/vocab.txt from cache at /home/jovyan/.cache/huggingface/transformers/0e1bbfda7f63a99bb52e3915dcf10c3c92122b827d92eb2d34ce94ee79ba486c.d789d64ebfe299b0e416afc4a169632f903f693095b4629a7ea271d5a0cf2c99
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer.json from cache at /home/jovyan/.cache/huggingface/transformers/75abb59d7a06f4f640158a9bfcde005264e59e8d566781ab1415b139d2e4c603.7f2721073f19841be16f41b0a70b600ca6b880c8f3df6f3535cbc704371bdfa4
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/distilbert-base-uncased/resolve/main/tokenizer_config.json from cache at /home/jovyan/.cache/huggingface/transformers/8c8624b8ac8aa99c60c912161f8332de003484428c47906d7ff7eb7f73eecdbb.20430bd8e10ef77a7d2977accefe796051e01bc2fc4aa146bc862997a1a15e79
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading configuration file https://huggingface.co/distilbert-base-uncased/resolve/main/config.json from cache at /home/jovyan/.cache/huggingface/transformers/23454919702d26495337f3da04d1655c7ee010d5ec9d77bdb9e399e00302c0a1.91b885ab15d631bf9cee9dc9d25ece0afd932f2f5130eba28f2055b2220c0333
# Model config DistilBertConfig {
#   "activation": "gelu",
#   "architectures": [
#     "DistilBertForMaskedLM"
#   ],
#   "attention_dropout": 0.1,
#   "dim": 768,
#   "dropout": 0.1,
#   "hidden_dim": 3072,
#   "initializer_range": 0.02,
#   "max_position_embeddings": 512,
#   "model_type": "distilbert",
#   "n_heads": 12,
#   "n_layers": 6,
#   "pad_token_id": 0,
#   "qa_dropout": 0.1,
#   "seq_classif_dropout": 0.2,
#   "sinusoidal_pos_embds": false,
#   "tie_weights_": true,
#   "transformers_version": "4.12.0",
#   "vocab_size": 30522
# }
#
# loading weights file https://huggingface.co/distilbert-base-uncased/resolve/main/pytorch_model.bin from cache at /home/jovyan/.cache/huggingface/transformers/9c169103d7e5a73936dd2b627e42851bec0831212b677c637033ee4bce9ab5ee.126183e36667471617ae2f0835fab707baa54b731f991507ebbb55ea85adb12a
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_projector.weight', 'vocab_layer_norm.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['pre_classifier.bias', 'classifier.weight', 'classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running training *****
#   Num examples = 53487
#   Num Epochs = 8
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 53488
# [2023-08-31T04:01:46] start training...
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
#     <div>
#
#       <progress value='26067' max='53488' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [26067/53488 1:13:52 < 1:17:43, 5.88 it/s, Epoch 3.90/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.000300</td>
#       <td>0.039599</td>
#       <td>0.991587</td>
#       <td>0.991618</td>
#       <td>0.991587</td>
#       <td>0.991587</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.000100</td>
#       <td>0.020351</td>
#       <td>0.996130</td>
#       <td>0.996134</td>
#       <td>0.996130</td>
#       <td>0.996130</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.000000</td>
#       <td>0.033693</td>
#       <td>0.995289</td>
#       <td>0.995294</td>
#       <td>0.995288</td>
#       <td>0.995289</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 5943
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-6686
# Configuration saved in results/checkpoint-6686/config.json
# Model weights saved in results/checkpoint-6686/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5943
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-13372
# Configuration saved in results/checkpoint-13372/config.json
# Model weights saved in results/checkpoint-13372/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}
# ***** Running Evaluation *****
#   Num examples = 5943
#   Batch size = 8
# Saving model checkpoint to results/checkpoint-20058
# Configuration saved in results/checkpoint-20058/config.json
# Model weights saved in results/checkpoint-20058/pytorch_model.bin
# <ipython-input-1-fce3f4a823d2>:31: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {k: torch.tensor(v[idx]) for k, v in self.encodings.items()}

# %%
print('hello')

# %%
# tokenizer = DistilBertTokenizerFast.from_pretrained(MODEL_NAME, do_lower_case=True)
# path_label = 'labels.json'
# path_test = 'data_model_relevants/202206171000_test.csv'
# name_train = '202206171000'
# path_output = 'output_noseed_anchor'
# max_length=512
# model = model_last

# (samples_test, _, indexs_label_test, _), target_names = read_passages(path_test, path_label, 0)
# labels_test = [target_names[index_label_test] for index_label_test in indexs_label_test]

# list_conf_output = []
# list_label_output = []
# list_answer_output = []

# for sample_test, label_origin in zip(samples_test, labels_test):
#     input_tokenized = tokenizer.encode_plus(sample_test, padding=True, truncation=True, max_length=max_length,
#                                             return_tensors='pt')
#     with torch.no_grad():
#         # out = model(**input_tokenized, output_hidden_states=True, output_attentions=True)
#         logits_this = predict_plus(input_tokenized, model)
#     # end

#     probas_evaluate = torch.nn.functional.softmax(logits_this, dim=-1)
#     answer_evaluate = int(probas_evaluate.argmax())
#     label_evaluate = target_names[answer_evaluate]

#     list_conf_output.append(probas_evaluate.numpy().tolist()[0][answer_evaluate])
#     list_label_output.append(label_evaluate)
#     list_answer_output.append(label_origin)
# # end

# print('[{}] finish testing.'.format(get_ts()))

# pairs_label_conf = [[a, b, c] for a, b, c in zip(list_label_output, list_conf_output, list_answer_output)]

# filename_output = f'output-{name_train}.json'
# path_file_output = os.path.join(path_output, filename_output)

# with open(path_file_output, 'w+') as file:
#     file.write(json.dumps(pairs_label_conf))
# # end

# print('[{}] main_train_and_evaluate finished.'.format(get_ts()))
