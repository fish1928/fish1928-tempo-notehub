# %%
from torch import nn
import torch

# %%
# nn.Linear(128,128).to('cuda')(torch.arange(3*64*128,dtype=torch.float32, device=torch.device('cuda')).view(3,64,128))
# Out:
# tensor([[[2.4113e+01, 5.5829e+01, 5.2431e+01,  ..., 9.6490e-01,
#           4.5015e+01, 5.4562e+01],
#          [9.0412e+01, 1.1018e+02, 1.3730e+02,  ..., 6.1393e+01,
#           1.5932e+02, 8.2527e+01],
#          [1.5671e+02, 1.6454e+02, 2.2218e+02,  ..., 1.2182e+02,
#           2.7362e+02, 1.1049e+02],
#          ...,
#          [4.0684e+03, 3.3715e+03, 5.2297e+03,  ..., 3.6871e+03,
#           7.0176e+03, 1.7605e+03],
#          [4.1347e+03, 3.4258e+03, 5.3145e+03,  ..., 3.7475e+03,
#           7.1319e+03, 1.7884e+03],
#          [4.2010e+03, 3.4802e+03, 5.3994e+03,  ..., 3.8079e+03,
#           7.2462e+03, 1.8164e+03]],
#
#         [[4.2673e+03, 3.5345e+03, 5.4843e+03,  ..., 3.8683e+03,
#           7.3605e+03, 1.8444e+03],
#          [4.3336e+03, 3.5889e+03, 5.5692e+03,  ..., 3.9288e+03,
#           7.4748e+03, 1.8723e+03],
#          [4.3999e+03, 3.6432e+03, 5.6540e+03,  ..., 3.9892e+03,
#           7.5891e+03, 1.9003e+03],
#          ...,
# ...
